# %% [markdown]
# # Preprocess

# %%
import os
import random
import pandas as pd
from IPython.display import display
from tqdm import tqdm
from pydub import AudioSegment

# %%
def count_files(folder_path):
    count = 0
    for root, dirs, files in os.walk(folder_path):
        count += len(files)
    return count

def find_folders(folder_path,n):
    folders = []
    for root, dirs, files in os.walk(folder_path):
        for dir in dirs:
            dir_path = os.path.join(root, dir)
            file_count = count_files(dir_path)
            if file_count > n:
                folders.append((dir, file_count))
    return folders

def find_folders_condition(folder_path,n,condition):
    folders = []
    for root, dirs, files in os.walk(folder_path):
        for dir in (filt_dirs for filt_dirs in dirs if filt_dirs in condition.keys()):
            dir_path = os.path.join(root, dir)
            file_count = count_files(dir_path)
            if file_count > n:
                folders.append((dir,condition[dir], file_count))
    return folders

# %%
# Set the root folder path
root_folder_path = './clips/'

# Find folders with more than 2000 files
folders = find_folders(root_folder_path,n=2000)

# Print the dataframe
print(folders)
display(pd.DataFrame(folders, columns=['Folder Title', 'Number of Elements']))

# Print the total number of folders
print(f"Total number of folders: {len(folders)}")
# Out:
# [('sound', 2769), ('movement', 2109), ('trying', 2215), ('friend', 2816), ('everyone', 3270), ('our', 6522), ('set', 3291), ('hey', 2482), ('tried', 2005), ('group', 3763), ('into', 9439), ('first', 15360), ('career', 2110), ('south', 3741), ('father', 3492), ('boy', 25100), ('currently', 2459), ('less', 2278), ('home', 5877), ('does', 5425), ('named', 5044), ('city', 7818), ('people', 13426), ('line', 3153), ('heard', 3422), ('answered', 3114), ('looking', 3402), ('eyes', 2750), ('university', 3862), ('wife', 2374), ('children', 4306), ('popular', 2639), ('anything', 4460), ('with', 23238), ('far', 2577), ('due', 2244), ('station', 4076), ('hear', 2161), ('the', 17671), ('number', 3607), ('seemed', 3555), ('those', 5688), ('things', 5738), ('after', 15292), ('never', 11274), ('part', 6425), ('gold', 2861), ('some', 17713), ('team', 2778), ('please', 4445), ('written', 2942), ('and', 116658), ('since', 3480), ('working', 2108), ('form', 2608), ('under', 4461), ('fire', 3314), ('table', 2126), ('mind', 3179), ('band', 2374), ('read', 3597), ('also', 30819), ('going', 10483), ('matter', 2845), ('through', 8848), ('little', 7560), ('which', 7162), ('son', 3194), ('quite', 2130), ('stop', 2398), ('saint', 2393), ('yes', 3316), ('two', 23105), ('remember', 2079), ('even', 5627), ('included', 2306), ('crystal', 2003), ('behind', 2291), ('away', 5004), ('state', 3539), ('years', 7022), ('community', 2433), ('water', 5023), ('every', 4626), ('full', 2356), ('played', 3385), ('death', 2565), ('states', 2626), ('united', 2863), ('better', 6111), ('early', 3631), ('different', 3478), ('sometimes', 3009), ('next', 4576), ('door', 2034), ('old', 9896), ('six', 4812), ('feel', 2115), ('building', 2939), ('books', 2423), ('held', 2415), ('north', 3700), ('new', 12813), ('course', 2254), ('red', 3693), ('word', 2311), ('without', 4437), ('black', 3390), ('thought', 9565), ('must', 6317), ('leave', 2159), ('continued', 2729), ('once', 3710), ('being', 4187), ('many', 13224), ('something', 5546), ('knew', 3611), ('would', 14717), ('main', 3044), ('morning', 3109), ('love', 5495), ('club', 2381), ('york', 2065), ('why', 8210), ('merchant', 2198), ('your', 18673), ('took', 5498), ('times', 3161), ('others', 2677), ('makes', 2643), ('office', 2930), ('series', 2463), ('country', 2092), ('around', 5920), ('before', 8571), ('general', 2350), ('same', 6102), ('seen', 5595), ('felt', 2705), ('tell', 5259), ('saw', 5446), ('work', 7944), ('than', 10161), ('nine', 3243), ('did', 14251), ('there', 31076), ('give', 3797), ('can', 25077), ('company', 3228), ('green', 2772), ('their', 18114), ('married', 2669), ('single', 2378), ('dog', 2024), ('not', 35454), ('girl', 3313), ('but', 34509), ('song', 2545), ('against', 2902), ('think', 9085), ('life', 6387), ('often', 5318), ('town', 6512), ('service', 2204), ('were', 36434), ('works', 2109), ('himself', 4178), ('want', 11166), ('language', 3295), ('album', 3235), ('passed', 2497), ('off', 6511), ('take', 6276), ('family', 3707), ('young', 4273), ('here', 10546), ('name', 8187), ('case', 2202), ('london', 2026), ('returned', 2558), ('important', 3133), ('more', 14397), ('term', 2092), ('party', 3298), ('throughout', 2099), ('very', 10256), ('great', 4253), ('about', 20701), ('man', 15272), ('usually', 2566), ('understand', 2561), ('star', 2127), ('school', 8305), ('include', 3234), ('head', 2690), ('doing', 3270), ('college', 3042), ('within', 3258), ('wait', 2038), ('call', 2430), ('came', 6626), ('fell', 2419), ('car', 2329), ('was', 140555), ('sand', 2539), ('today', 3988), ('hot', 2034), ('among', 3066), ('right', 7558), ('been', 16643), ('own', 4584), ('business', 2487), ('ten', 2165), ('however', 7771), ('common', 2610), ('looked', 3950), ('short', 2346), ('known', 7099), ('back', 9165), ('sure', 2972), ('following', 3092), ('daughter', 2072), ('built', 2998), ('king', 2908), ('food', 2192), ('men', 5253), ('near', 3321), ('put', 3307), ('everything', 4534), ('done', 3665), ('again', 5742), ('end', 397 ...
#     Folder Title  Number of Elements
# 0          sound                2769
# 1       movement                2109
# 2         trying                2215
# 3         friend                2816
# 4       everyone                3270
# ..           ...                 ...
# 454         blue                2983
# 455          top                3086
# 456         like               16353
# 457          has                7314
# 458       island                2140
#
# [459 rows x 2 columns]
# Total number of folders: 459

# %%
phoneme_list={
    "party"    :  "/p/" , 
    "books"    :  "/b/" , 
    "trying"   :  "/t/" , 
    "different":  "/d/" , 
    "county"   :  "/k/" , 
    "game"     :  "/g/" ,
    "felt"     :  "/f/" , 
    "love"     :  "/v/" , 
    "thing"    :  "/θ/" ,  
    "then"     :  "/ð/" ,  
    "sun"      :  "/s/" , 
    "has"      :  "/z/" , 
    "sure"     :  "/ʃ/" ,  
    "treasure" : " /ʒ/" ,
    "church"   : "/tʃ/" ,
    "general"  : "/dʒ/" ,
    "who"      :  "/h/" ,  
    "man"      :  "/m/" ,  
    "need"     :  "/n/" , 
    "song"     :  "/ŋ/" ,  
    "live"     :  "/l/" ,  
    "run"      :  "/r/" ,  
    "why"      :  "/w/" ,  
    "you"      :  "/j/" ,  
    "people"   : "/iː/" , 
    "river"    :  "/ɪ/" ,  
    "end"      :  "/e/" ,  
    "friend"   :  "/ɛ/" ,
    "back"     :  "/æ/" , 
    "does"     :  "/ʌ/" ,  
    "about"    :  "/ə/" ,  
    "car"      : "/ɑː/" , 
    "door"     : "/ɔː/" , 
    "boy"      : "/ɔɪ/" , 
    "side"     : "/aɪ/" , 
    "now"      : "/aʊ/" , 
    "day"      : "/eɪ/" , 
    "here"     : "/ɪə/" , 
    "our"      : "/ʊə/" , 
    "service"  : "/ər/" ,  
    "words"    : "/ɜː/" ,  
    "open"     : "/oʊ/" , 
    "north"    :"/ɔːr/" ,
    "put"      :  "/ʊ/" 
}
random_words=[
    "tried",
    "hey",
    "career",
    "south",
    "please",
    "working",
    "building",
    "old",
    "around",
    "company",
    "himself",
    "language",
    "album",
    "family",
    "young",
    "returned",
    "important",
    "throughout",
    "understand",
    "include",
    "business",
    "daughter",
    "everything",
    "englishman",
    "between",
    "outside",
]

# %%
# Find folders with more than 2000 files
phoneme_folders = find_folders_condition(root_folder_path,n=1,condition=phoneme_list)

# Create the dataframe
df2 = pd.DataFrame(phoneme_folders, columns=['Folder Title','Phoneme', 'Number of Elements'])
display(df2)
# Out:
#    Folder Title Phoneme  Number of Elements
# 0        trying     /t/                2215
# 1        friend     /ɛ/                2816
# 2           our    /ʊə/                6522
# 3           boy    /ɔɪ/               25100
# 4          does     /ʌ/                5425
# 5        people    /iː/               13426
# 6     different     /d/                3478
# 7          door    /ɔː/                2034
# 8         books     /b/                2423
# 9         north   /ɔːr/                3700
# 10         love     /v/                5495
# 11          why     /w/                8210
# 12      general    /dʒ/                2350
# 13         felt     /f/                2705
# 14         song     /ŋ/                2545
# 15      service    /ər/                2204
# 16         here    /ɪə/               10546
# 17        party     /p/                3298
# 18        about     /ə/               20701
# 19          man     /m/               15272
# 20          car    /ɑː/                2329
# 21         back     /æ/                9165
# 22         sure     /ʃ/                2972
# 23          put     /ʊ/                3307
# 24          end     /e/                3979
# 25     treasure     /ʒ/                2529
# 26         game     /g/                3569
# 27          day    /eɪ/                8497
# 28          now    /aʊ/               13075
# 29        thing     /θ/                4207
# 30         open    /oʊ/                3042
# 31         then     /ð/               15042
# 32       church    /tʃ/                2486
# 33         need     /n/                6268
# 34         side    /aɪ/                2733
# 35        words    /ɜː/                2758
# 36          you     /j/               87515
# 37         live     /l/                3504
# 38        river     /ɪ/                3735
# 39          sun     /s/                3522
# 40          run     /r/                2139
# 41       county     /k/                4371
# 42          who     /h/               12017
# 43          has     /z/                7314

# %%
def copy_random_files(source_dir, dest_dir,dir_list, num_files_per_folder):
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
    
    for root, dirs, files in os.walk(source_dir):
        for folder in (filt_dirs for filt_dirs in dirs if filt_dirs in dir_list):
            folder_path = os.path.join(root, folder)
            files_in_folder = os.listdir(folder_path)
            random_files = random.sample(files_in_folder, num_files_per_folder)

            for file_name in tqdm(random_files,desc="Copying and downsampling \'"+folder+"\' files"):
                source_file_path = os.path.join(folder_path, file_name)
                if not os.path.exists(os.path.join(dest_dir,folder)):
                    os.makedirs(os.path.join(dest_dir,folder))
                dest_file_path = os.path.join(dest_dir,folder,file_name)
                audio = AudioSegment.from_file(source_file_path)
                audio = audio.set_frame_rate(16000)
                audio.export(dest_file_path[:-4]+"wav", format='wav')


    print(f"{num_files_per_folder} files in each of the {len(dir_list)} folders copied successfully!")

copy_random_files('./clips/', './subset/',list(phoneme_list.keys())+random_words, 2000)
# Out:
# Copying and downsampling 'trying' files: 100%|██████████| 2000/2000 [00:46<00:00, 43.02it/s]
# Copying and downsampling 'friend' files: 100%|██████████| 2000/2000 [00:49<00:00, 40.68it/s]
# Copying and downsampling 'our' files: 100%|██████████| 2000/2000 [00:43<00:00, 45.55it/s]
# Copying and downsampling 'hey' files: 100%|██████████| 2000/2000 [00:49<00:00, 40.63it/s]
# Copying and downsampling 'tried' files: 100%|██████████| 2000/2000 [00:44<00:00, 45.10it/s]
# Copying and downsampling 'career' files: 100%|██████████| 2000/2000 [00:45<00:00, 43.79it/s]
# Copying and downsampling 'south' files: 100%|██████████| 2000/2000 [00:45<00:00, 43.51it/s]
# Copying and downsampling 'boy' files: 100%|██████████| 2000/2000 [00:43<00:00, 46.16it/s]
# Copying and downsampling 'does' files: 100%|██████████| 2000/2000 [00:43<00:00, 46.03it/s]
# Copying and downsampling 'people' files: 100%|██████████| 2000/2000 [00:43<00:00, 46.25it/s]
# Copying and downsampling 'please' files: 100%|██████████| 2000/2000 [00:44<00:00, 44.57it/s]
# Copying and downsampling 'working' files: 100%|██████████| 2000/2000 [00:46<00:00, 42.57it/s]
# Copying and downsampling 'different' files: 100%|██████████| 2000/2000 [00:48<00:00, 41.59it/s]
# Copying and downsampling 'door' files: 100%|██████████| 2000/2000 [00:45<00:00, 44.21it/s]
# Copying and downsampling 'old' files: 100%|██████████| 2000/2000 [00:44<00:00, 45.19it/s]
# Copying and downsampling 'building' files: 100%|██████████| 2000/2000 [00:50<00:00, 39.91it/s]
# Copying and downsampling 'books' files: 100%|██████████| 2000/2000 [00:49<00:00, 40.16it/s]
# Copying and downsampling 'north' files: 100%|██████████| 2000/2000 [00:47<00:00, 42.42it/s]
# Copying and downsampling 'love' files: 100%|██████████| 2000/2000 [00:44<00:00, 45.08it/s]
# Copying and downsampling 'why' files: 100%|██████████| 2000/2000 [00:43<00:00, 45.92it/s]
# Copying and downsampling 'around' files: 100%|██████████| 2000/2000 [00:43<00:00, 45.59it/s]
# Copying and downsampling 'general' files: 100%|██████████| 2000/2000 [00:50<00:00, 39.54it/s]
# Copying and downsampling 'felt' files: 100%|██████████| 2000/2000 [00:50<00:00, 39.57it/s]
# Copying and downsampling 'company' files: 100%|██████████| 2000/2000 [00:44<00:00, 45.24it/s]
# Copying and downsampling 'song' files: 100%|██████████| 2000/2000 [00:50<00:00, 39.56it/s]
# Copying and downsampling 'service' files: 100%|██████████| 2000/2000 [00:49<00:00, 40.27it/s]
# Copying and downsampling 'himself' files: 100%|██████████| 2000/2000 [00:45<00:00, 43.58it/s]
# Copying and downsampling 'language' files: 100%|██████████| 2000/2000 [00:47<00:00, 42.47it/s]
# Copying and downsampling 'album' files: 100%|██████████| 2000/2000 [00:48<00:00, 40.93it/s]
# Copying and downsampling 'family' files: 100%|██████████| 2000/2000 [00:46<00:00, 42.95it/s]
# Copying and downsampling 'young' files: 100%|██████████| 2000/2000 [00:44<00:00, 44.65it/s]
# Copying and downsampling 'here' files: 100%|██████████| 2000/2000 [00:41<00:00, 47.79it/s]
# Copying and downsampling 'returned' files: 100%|██████████| 2000/2000 [00:49<00:00, 40.03it/s]
# Copying and downsampling 'important' files: 100%|██████████| 2000/2000 [00:46<00:00, 42.66it/s]
# Copying and downsampling 'party' files: 100%|██████████| 2000/2000 [00:46<00:00, 43.30it/s]
# Copying and downsampling 'throughout' files: 100%|██████████| 2000/2000 [00:47<00:00, 41.95it/s]
# Copying and downsampling 'about' files: 100%|██████████| 2000/2000 [00:43<00:00, 46.11it/s]
# Copying and downsampling 'man' files: 100%|██████████| 2000/2000 [00:44<00:00, 45.32it/s]
# Copying and downsampling 'understand' files: 100%|██████████| 2000/2000 [00:48<00:00, 41.13it/s]
# Copying and downsampling 'include' files: 100%|██████████| 2000/2000 [00:47<00:00, 41.90it/s]
# Copying and downsampling 'car' files: 100%|██████████| 2000/2000 [00:49<00:00, 40.80it/s]
# Copying and downsampling 'business' files: 100%|██████████| 2000/2000 [00:49<00:00, 40.49it/s]
# Copying and downsampling 'back' files: 100%|██████████| 2000/2000 [00:43<00:00, 45.58it/s]
# Copying and downsampling 'sure' files: 100%|██████████| 2000/2000 [00:48<00:00, 41.35it/s]
# Copying and downsampling 'daughter' files: 100%|██████████| 2000/2000 [00:46<00:00, 43.05it/s]
# Copying and downsampling 'put' files: 100%|██████████| 2000/2000 [00:46<00:00, 43.46it/s]
# Copying and downsampling 'everything' files: 100%|██████████| 2000/2000 [00:45<00:00, 43.75it/s]
# Copying and downsampling 'end' files: 100%|██████████| 2000/2000 [00:44<00:00, 45.08it/s]
# Copying and downsampling 'englishman' files: 100%|██████████| 2000/2000 [00:48<00:00, 41.38it/s]
# Copying and downsampling 'between' files: 100%|██████████| 2000/2000 [00:42<00:00, 46.66it/s]
# Copying and downsampling 'treasure' files: 100%|██████████| 2000/2000 [00:48<00:00, 41.59it/s]
# Copying and downsampling 'game' files: 100%|██████████| 2000/2000 [00:45<00:00, 43.99it/s]
# Copying and downsampling 'outside' files: 100%|██████████| 2000/2000 [00:44<00:00, 44.61it/s]
# Copying and downsampling 'day' files: 100%|██████████| 2000/2000 [00:42<00:00, 47.27it/s]
# Copying and downsampling 'now' files: 100%|██████████| 2000/2000 [00:43<00:00, 46.10it/s]
# Copying and downsampling 'thing' files: 100%|██████████| 2000/2000 [00:46<00:00, 43.26it/s]
# Copying and downsampling 'open' files: 100%|██████████| 2000/2000 [00:45<00:00, 44.11it/s]
# Copying and downsampling 'then' files: 100%|██████████| 2000/2000 [00:42<00:00, 46.87it/s]
# Copying and downsampling 'church' files: 100%|██████████| 2000/2000 [00:49<00:00, 40.57it/s]
# Copying and downsampling 'need' files: 100%|██████████| 2000/2000 [00:44<00:00, 44.52it/s]
# Copying and downsampling 'side' files: 100%|██████████| 2000/2000 [00:48<00:00, 41.34it/s]
# Copying and downsampling 'words' files: 100%|██████████| 2000/2000 [00:48<00:00, 41.13it/s]
# Copying and downsampling 'you' files: 100%|██████████| 2000/2000 [00:43<00:00, 46.41it/s]
# Copying and downsampling 'live' files: 100%|██████████| 2000/2000 [00:47<00:00, 42.41it/s]
# Copying and downsampling 'river' files: 100%|██████████| 2000/2000 [00:45<00:00, 44.05it/s]
# Copying and downsampling 'sun' files: 100%|██████████| 2000/2000 [00:44<00:00, 44.58it/s]
# Copying and downsampling 'run' files: 100%|██████████| 2000/2000 [00:47<00:00, 41.83it/s]
# Copying and downsampling 'county' files: 100%|██████████| 2000/2000 [00:45<00:00, 44.31it/s]
# Copying and downsampling 'who' files: 100%|██████████| 2000/2000 [00:44<00:00, 45.29it/s]
# Copying and downsampling 'has' files: 100%|██████████| 2000/2000 [00:43<00:00, 46.41it/s]
# 2000 files in each of the 70 folders copied successfully!
